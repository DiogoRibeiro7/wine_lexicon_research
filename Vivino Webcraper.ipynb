# %% [markdown]
# ## Vivino Webscraper
#
# #### Introduction:
# Vivino is a popular wine enthusiast website database of information about wine from around the world. This project is a proof of concept for scraping data from Vivino for the purposes of wine understanding the wine market in Spain. This proof of concept has some limitations. First, the list of wines scraped are not a complete and comprehensive view of Spanish wine, as wine culture in Spain has traditionally been that of small production and barrel sales. For this reason, many small wine producers are not included in Vivinos database and therefore not represented in the data. Second, the wines shown only include wines currently available for purchase. Lastly, as a consumer database, the results of ratings may not represent professional opinions and may be limited by the 5-star rating system due to its overly simplistic nature.

# %%
import requests
import json
import pandas as pd
import time

# Instantiate a dictionary of headers
# We only need to `manipulate` an User-Agent key
headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:89.0) Gecko/20100101 Firefox/89.0",
}

# Instantiate a dictionary of query strings
# Defines the only needed payload
payload = {
        "country_codes[]": ["es"],  # "FR", "IT", "DE", "CL", "PT", "AU", "AT", "AR", "US" <-- can add more country codes here
        "currency_code": "EUR",
        "grape_filter": "varietal",
        "min_rating": "1",
        "order_by": "price",
        "order": "asc",
        "page": 1,
        "price_range_max": "500",
        "price_range_min": "0",
        "wine_type_ids[]": "1",
}

# Performs an initial request and gathers the amount of results
r = requests.get('https://www.vivino.com/api/explore/explore?',
                 params=payload, headers=headers)
n_matches = r.json()['explore_vintage']['records_matched']

# %%
# Create Dataframe
column_names=["Winery", "Year", "Wine ID", "Wine", "Rating", "num_review", "price",'Country','Region']
df = pd.DataFrame(columns = column_names)

# %%
# Iterates through the amount of possible pages
# A page is defined by n_matches divided by 25 (number of results per page)
for i in range(int(n_matches / 25)):
    # Adds the page on the payload
    payload['page'] = i + 1

    print(f'Requesting data from page: {payload["page"]}')

    # Performs the request and saves the matches
    r = requests.get('https://www.vivino.com/api/explore/explore?',
                 params=payload, headers=headers)
    # matches = r.json()['explore_vintage']['matches']
    results = [
        (
            t["vintage"]["wine"]["winery"]["name"],
            t["vintage"]["year"],
            t["vintage"]["wine"]["id"],
            f'{t["vintage"]["wine"]["name"]} {t["vintage"]["year"]}',
            t["vintage"]["statistics"]["ratings_average"],
            t["vintage"]["statistics"]["ratings_count"],
            t["prices"][0]["amount"],
            t['vintage']['wine']['region']['country']['name'],
            t['vintage']['wine']['region']['name'],

        )
        for t in r.json()["explore_vintage"]["matches"] 
    ]       

    df2 = pd.DataFrame(results, columns=column_names)
    df = df.append(df2)
# Out:
# Requesting data from page: 1
# Requesting data from page: 2
# Requesting data from page: 3
# Requesting data from page: 4
# Requesting data from page: 5
# Requesting data from page: 6
# Requesting data from page: 7
# Requesting data from page: 8
# Requesting data from page: 9
# Requesting data from page: 10
# Requesting data from page: 11
# Requesting data from page: 12
# Requesting data from page: 13
# Requesting data from page: 14
# Requesting data from page: 15
# Requesting data from page: 16
# Requesting data from page: 17
# Requesting data from page: 18
# Requesting data from page: 19
# Requesting data from page: 20
# Requesting data from page: 21
# Requesting data from page: 22
# Requesting data from page: 23
# Requesting data from page: 24
# Requesting data from page: 25
# Requesting data from page: 26
# Requesting data from page: 27
# Requesting data from page: 28
# Requesting data from page: 29
# Requesting data from page: 30
# Requesting data from page: 31
# Requesting data from page: 32
# Requesting data from page: 33
# Requesting data from page: 34
# Requesting data from page: 35
# Requesting data from page: 36
# Requesting data from page: 37
# Requesting data from page: 38
# Requesting data from page: 39
# Requesting data from page: 40
# Requesting data from page: 41
# Requesting data from page: 42
# Requesting data from page: 43
# Requesting data from page: 44
# Requesting data from page: 45
# Requesting data from page: 46
# Requesting data from page: 47
# Requesting data from page: 48
# Requesting data from page: 49
# Requesting data from page: 50
# Requesting data from page: 51
# Requesting data from page: 52
# Requesting data from page: 53
# Requesting data from page: 54
# Requesting data from page: 55
# Requesting data from page: 56
# Requesting data from page: 57
# Requesting data from page: 58
# Requesting data from page: 59
# Requesting data from page: 60
# Requesting data from page: 61
# Requesting data from page: 62
# Requesting data from page: 63
# Requesting data from page: 64
# Requesting data from page: 65
# Requesting data from page: 66
# Requesting data from page: 67
# Requesting data from page: 68
# Requesting data from page: 69
# Requesting data from page: 70
# Requesting data from page: 71
# Requesting data from page: 72
# Requesting data from page: 73
# Requesting data from page: 74
# Requesting data from page: 75
# Requesting data from page: 76
# Requesting data from page: 77
# Requesting data from page: 78
# Requesting data from page: 79
# Requesting data from page: 80
# Requesting data from page: 81
# Requesting data from page: 82
# Requesting data from page: 83
# Requesting data from page: 84
# Requesting data from page: 85
# Requesting data from page: 86
# Requesting data from page: 87
# Requesting data from page: 88
# Requesting data from page: 89
# Requesting data from page: 90
# Requesting data from page: 91
# Requesting data from page: 92
# Requesting data from page: 93
# Requesting data from page: 94
# Requesting data from page: 95
# Requesting data from page: 96
# Requesting data from page: 97
# Requesting data from page: 98
# Requesting data from page: 99
# Requesting data from page: 100
# Requesting data from page: 101
# Requesting data from page: 102
# Requesting data from page: 103
# Requesting data from page: 104
# Requesting data from page: 105
# Requesting data from page: 106
# Requesting data from page: 107
# Requesting data from page: 108
# Requesting data from page: 109
# Requesting data from page: 110
# Requesting data from page: 111
# Requesting data from page: 112
# Requesting data from page: 113
# Requesting data from page: 114
# Requesting data from page: 115
# Requesting data from page: 116
# Requesting data from page: 117
# Requesting data from page: 118
# Requesting data from page: 119
# Requesting data from page: 120
# Requesting data from page: 121
# Requesting data from page: 122
# Requesting data from page: 123
# Requesting data from page: 124
# Requesting data from page: 125
# Requesting data from page: 126
# Requesting data from page: 127
# Requesting data from page: 128
# Requesting data from page: 129
# Requesting data from page: 130
# Requesting data from page: 131
# Requesting data from page: 132
# Requesting data from page: 133
# Requesting data from page: 134
# Requesting data from page: 135
# Requesting data from page: 136
# Requesting data from page: 137
# Requesting data from page: 138
# Requesting data from page: 139
# Requesting data from page: 140
# Requesting data from page: 141
# Requesting data from page: 142
# Requesting data from page: 143
# Requesting data from page: 144
# Requesting data from page: 145
# Requesting data from page: 146
# Requesting data from page: 147
# Requesting data from page: 148
# Requesting data from page: 149
# Requesting data from page: 150
# Requesting data from page: 151
# Requesting data from page: 152
# Requesting data from page: 153
# Requesting data from page: 154
# Requesting data from page: 155
# Requesting data from page: 156
# Requesting data from page: 157
# Requesting data from page: 158
# Requesting data from page: 159
# Requesting data from page: 160
# Requesting data from page: 161
# Requesting data from page: 162
# Requesting data from page: 163
# Requesting data from page: 164
# Requesting data from page: 165
# Requesting data from page: 166
# Requesting data from page: 167
# Requesting data from page: 168
# Requesting data from page: 169
# Requesting data from page: 170
# Requesting data from page: 171
# Requesting data from page: 172
# Requesting data from page: 173
# Requesting data from page: 174
# Requesting data from page: 175
# Requesting data from page: 176
# Requesting data from page: 177
# Requesting data from page: 178
# Requesting data from page: 179
# Requesting data from page: 180
# Requesting data from page: 181
# Requesting data from page: 182
# Requesting data from page: 183
# Requesting data from page: 184
# Requesting data from page: 185
# Requesting data from page: 186
# Requesting data from page: 187
# Requesting data from page: 188
# Requesting data from page: 189
# Requesting data from page: 190
# Requesting data from page: 191
# Requesting data from page: 192
# Requesting data from page: 193
# Requesting data from page: 194
# Requesting data from page: 195
# Requesting data from page: 196
# Requesting data from page: 197
# Requesting data from page: 198
# Requesting data from page: 199
# Requesting data from page: 200
# Requesting data from page: 201
# Requesting data from page: 202
# Requesting data from page: 203
# Requesting data from page: 204
# Requesting data from page: 205
# Requesting data from page: 206
# Requesting data from page: 207
# Requesting data from page: 208
# Requesting data from page: 209
# Requesting data from page: 210
# Requesting data from page: 211
# Requesting data from page: 212
# Requesting data from page: 213
# Requesting data from page: 214
# Requesting data from page: 215
# Requesting data from page: 216
# Requesting data from page: 217
# Requesting data from page: 218
# Requesting data from page: 219
# Requesting data from page: 220
# Requesting data from page: 221
# Requesting data from page: 222
# Requesting data from page: 223
# Requesting data from page: 224
# Requesting data from page: 225
# Requesting data from page: 226
# Requesting data from page: 227
# Requesting data from page: 228
# Requesting data from page: 229
# Requesting data from page: 230
# Requesting data from page: 231
# Requesting data from page: 232
# Requesting data from page: 233
# Requesting data from page: 234
# Requesting data from page: 235
# Requesting data from page: 236
# Requesting data from page: 237
# Requesting data from page: 238
# Requesting data from page: 239
# Requesting data from page: 240
# Requesting data from page: 241
# Requesting data from page: 242
# Requesting data from page: 243
# Requesting data from page: 244
# Requesting data from page: 245
# Requesting data from page: 246
# Requesting data from page: 247
# Requesting data from page: 248
# Requesting data from page: 249
# Requesting data from page: 250
# Requesting data from page: 251
# Requesting data from page: 252
# Requesting data from page: 253
# Requesting data from page: 254
# Requesting data from page: 255
# Requesting data from page: 256
# Requesting data from page: 257
# Requesting data from page: 258
# Requesting data from page: 259
# Requesting data from page: 260
# Requesting data from page: 261
# Requesting data from page: 262
# Requesting data from page: 263
# Requesting data from page: 264
# Requesting data from page: 265
# Requesting data from page: 266
# Requesting data from page: 267
# Requesting data from page: 268
# Requesting data from page: 269
# Requesting data from page: 270
# Requesting data from page: 271
# Requesting data from page: 272
# Requesting data from page: 273
# Requesting data from page: 274
# Requesting data from page: 275
# Requesting data from page: 276
# Requesting data from page: 277
# Requesting data from page: 278
# Requesting data from page: 279
# Requesting data from page: 280
# Requesting data from page: 281
# Requesting data from page: 282
# Requesting data from page: 283
# Requesting data from page: 284
# Requesting data from page: 285
# Requesting data from page: 286
# Requesting data from page: 287
# Requesting data from page: 288
# Requesting data from page: 289
# Requesting data from page: 290
# Requesting data from page: 291
# Requesting data from page: 292
# Requesting data from page: 293
# Requesting data from page: 294
# Requesting data from page: 295
# Requesting data from page: 296
# Requesting data from page: 297
# Requesting data from page: 298
# Requesting data from page: 299
# Requesting data from page: 300
# Requesting data from page: 301
# Requesting data from page: 302
# Requesting data from page: 303
# Requesting data from page: 304
# Requesting data from page: 305
# Requesting data from page: 306
# Requesting data from page: 307
# Requesting data from page: 308
# Requesting data from page: 309
# Requesting data from page: 310
# Requesting data from page: 311
# Requesting data from page: 312
# Requesting data from page: 313
# Requesting data from page: 314
# Requesting data from page: 315
# Requesting data from page: 316
# Requesting data from page: 317
# Requesting data from page: 318
# Requesting data from page: 319
# Requesting data from page: 320
# Requesting data from page: 321
# Requesting data from page: 322
# Requesting data from page: 323
# Requesting data from page: 324
# Requesting data from page: 325
# Requesting data from page: 326
# Requesting data from page: 327
# Requesting data from page: 328
# Requesting data from page: 329
# Requesting data from page: 330
# Requesting data from page: 331
# Requesting data from page: 332
# Requesting data from page: 333
# Requesting data from page: 334
# Requesting data from page: 335
# Requesting data from page: 336
# Requesting data from page: 337
# Requesting data from page: 338
# Requesting data from page: 339
# Requesting data from page: 340
# Requesting data from page: 341
# Requesting data from page: 342
# Requesting data from page: 343
# Requesting data from page: 344
# Requesting data from page: 345
# Requesting data from page: 346

# %%
df
# Out:
#                                Winery  Year  Wine ID  \
# 0                           Viña Oria  2019  1812139
# 1                               Ayuso  2017  2084964
# 2                   Castillo de Liria  2020  1643745
# 3                   Castillo de Liria  2019  1643745
# 4          Finca Venta de Don Quijote  2020  7166356
# ..                                ...   ...      ...
# 20                             Loxera  2017  1895952
# 21  Vinos del Viento - Michael Cooper  2015  5049890
# 22                              Luzon  2018  1230455
# 23                           Tridente  2018  2185839
# 24                   Bodega de Bardos  2016  6773233
#
#                                 Wine  Rating num_review  price Country  \
# 0                      Garnacha 2019     3.5        327   2.50  España
# 1        Abadia del Roble Tinto 2017     2.9         52   2.54  España
# 2                Bobal - Shiraz 2020     3.4         85   2.56  España
# 3                Bobal - Shiraz 2019     3.6        305   2.56  España
# 4           Tempranillo - Syrah 2020     3.6        129   2.72  España
# ..                               ...     ...        ...    ...     ...
# 20      Sentada Sobre la Bestia 2017     3.7        116  12.90  España
# 21  Seleccion Especial Cariñena 2015     4.0         51  12.90  España
# 22               Altos de Luzón 2018     3.9        261  12.90  España
# 23         Triton Tinta de Toro 2018     3.8        174  12.90  España
# 24                      Reserva 2016     4.1       1878  12.90  España
#
#               Region
# 0           Cariñena
# 1          La Mancha
# 2           Valencia
# 3           Valencia
# 4           Castilla
# ..               ...
# 20          Valencia
# 21          Cariñena
# 22           Jumilla
# 23              Toro
# 24  Ribera del Duero
#
# [8650 rows x 9 columns]

# %%
 # Iterates through every match
    for result in results:
        # Defines the wine's identifier
        _id = result['Wine ID']

        # Defines a page counter
        page_counter = 1

        # Performs an all-time true loop
        while True:
            print(f'Requesting reviews from wine: {_id} and page: {page_counter}')

            # Performs the request and saves the reviews
            r = requests.get(f'https://www.vivino.com/api/wines/{_id}/reviews?per_page=50&page={page_counter}',
                            # headers=headers)
            reviews = r.json()['reviews']
            df = df.append(reviews)

           print(f'Number of reviews: {len(reviews)}')

            # If there are no reviews anymore,
            # it indicates that the loop can be broken
           if len(reviews) == 0:
                # Breaks the loop
                break

            # Otherwise, increments the counter
           page_counter += 1

# %%
df.to_csv(r"C:\SD card\Documents\Data Analytics\Vivino Webscraper\vivino.csv", index=False)
